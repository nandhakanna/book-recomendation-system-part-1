# %%
import pandas as pd # for manipulation of  tabular data
import numpy as np # for numeric python

# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_books=pd.read_csv("Books.csv")
df_books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford               2002.0     Oxford University Press
# 1  Richard Bruce Wright               2001.0       HarperFlamingo Canada
# 2          Carlo D'Este               1991.0             HarperPerennial
# 3      Gina Bari Kolata               1999.0        Farrar Straus Giroux
# 4       E. J. W. Barber               1999.0  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
df_ratings=pd.read_csv("Ratings.csv")
df_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df_users=pd.read_csv("Users.csv")
df_users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# ###### Data Information

# %%
df_books.info()  #informatiom about df_books
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105694 entries, 0 to 105693
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 105694 non-null  object
#  1   Book-Title           105694 non-null  object
#  2   Book-Author          105694 non-null  object
#  3   Year-Of-Publication  105693 non-null  float64
#  4   Publisher            105693 non-null  object
#  5   Image-URL-S          105693 non-null  object
#  6   Image-URL-M          105693 non-null  object
#  7   Image-URL-L          105693 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 6.5+ MB

# %%
df_books.describe()
# Out:
#        Year-Of-Publication
# count        105693.000000
# mean           1959.313294
# std             261.992767
# min               0.000000
# 25%            1990.000000
# 50%            1996.000000
# 75%            2000.000000
# max            2050.000000

# %%
df_books.duplicated().sum()
# Out:
# 0

# %%
df_books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014705 entries, 0 to 1014704
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1014705 non-null  int64
#  1   ISBN         1014705 non-null  object
#  2   Book-Rating  1014705 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 23.2+ MB

# %%
df_ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.014705e+06  1.014705e+06
# mean   1.245563e+05  2.881035e+00
# std    7.216964e+04  3.857648e+00
# min    2.000000e+00  0.000000e+00
# 25%    6.047500e+04  0.000000e+00
# 50%    1.252030e+05  0.000000e+00
# 75%    1.865700e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
df_ratings.describe(include = 'O')
# Out:
#               ISBN
# count      1014705
# unique      316491
# top     0971880107
# freq          2181

# %%
df_ratings.duplicated().sum()
# Out:
# 0

# %%
df_ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
df_users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
df_users.duplicated().sum()
# Out:
# 0

# %%
df_users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# ###### Unique values

# %%
def unique_values(dataset):
  """
  function : unique_values
  description : this takes a dataset and return unique values of each and every column/feature.
  return type : dataframe
  """

  list_unique_valeus = [dataset[col].nunique() for col in dataset.columns]
  list_cols = dataset.columns.tolist()
  data = list(zip(list_cols,list_unique_valeus))
  df = pd.DataFrame(data,columns = ['Column','No of Unique Values'])
  return df

# %%
unique_values(df_books)
# Out:
#                 Column  No of Unique Values
# 0                 ISBN               105694
# 1           Book-Title                96009
# 2          Book-Author                43943
# 3  Year-Of-Publication                   93
# 4            Publisher                 8180
# 5          Image-URL-S               105637
# 6          Image-URL-M               105637
# 7          Image-URL-L               105637

# %%
unique_values(df_ratings)
# Out:
#         Column  No of Unique Values
# 0      User-ID                92571
# 1         ISBN               316491
# 2  Book-Rating                   11

# %%
unique_values(df_users)
# Out:
#      Column  No of Unique Values
# 0   User-ID               278858
# 1  Location                57339
# 2       Age                  165

# %% [markdown]
# ###### Merging the data frames

# %%
merged_df=pd.merge(df_users,df_ratings,on='User-ID') # merging df_users with df_ratings based on User-ID
merged_df=pd.merge(merged_df,df_books,on='ISBN') # merging  merged_df with df_books base

# %%
merged_df.head()
# Out:
#    User-ID                   Location   Age        ISBN  Book-Rating  \
# 0        2  stockton, california, usa  18.0  0195153448            0
# 1        8   timmins, ontario, canada   NaN  0002005018            5
# 2    11400    ottawa, ontario, canada  49.0  0002005018            0
# 3    11676              n/a, n/a, n/a   NaN  0002005018            8
# 4    41385   sudbury, ontario, canada   NaN  0002005018            0
#
#             Book-Title           Book-Author  Year-Of-Publication  \
# 0  Classical Mythology    Mark P. O. Morford               2002.0
# 1         Clara Callan  Richard Bruce Wright               2001.0
# 2         Clara Callan  Richard Bruce Wright               2001.0
# 3         Clara Callan  Richard Bruce Wright               2001.0
# 4         Clara Callan  Richard Bruce Wright               2001.0
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...

# %%
merged_df.columns
# Out:
# Index(['User-ID', 'Location', 'Age', 'ISBN', 'Book-Rating', 'Book-Title',
#        'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-S',
#        'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 673341 entries, 0 to 673340
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   User-ID              673341 non-null  int64
#  1   Location             673341 non-null  object
#  2   Age                  489679 non-null  float64
#  3   ISBN                 673341 non-null  object
#  4   Book-Rating          673341 non-null  int64
#  5   Book-Title           673341 non-null  object
#  6   Book-Author          673341 non-null  object
#  7   Year-Of-Publication  673339 non-null  float64
#  8   Publisher            673339 non-null  object
#  9   Image-URL-S          673339 non-null  object
#  10  Image-URL-M          673339 non-null  object
#  11  Image-URL-L          673339 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 66.8+ MB

# %%
merged_df.shape  #size of the dataset
# Out:
# (673341, 12)

# %%
merged_df.duplicated().sum() #Number of duplicates in the dataset
# Out:
# 0

# %%
merged_df.isnull().sum() #Null values in the dataset
# Out:
# User-ID                     0
# Location                    0
# Age                    183662
# ISBN                        0
# Book-Rating                 0
# Book-Title                  0
# Book-Author                 0
# Year-Of-Publication         2
# Publisher                   2
# Image-URL-S                 2
# Image-URL-M                 2
# Image-URL-L                 2
# dtype: int64

# %%
#Dropping the unnessary columns
merged_df.drop(['Image-URL-S', 'Image-URL-M', 'Image-URL-L'],axis=1,inplace=True) # using drop method of dataframe object

# %%
# replacing '-' to '_' from the column name
merged_df.columns= merged_df.columns.str.replace('-', '_')

# %%
merged_df.columns
# Out:
# Index(['User_ID', 'Location', 'Age', 'ISBN', 'Book_Rating', 'Book_Title',
#        'Book_Author', 'Year_Of_Publication', 'Publisher'],
#       dtype='object')

# %%
#Extrating only the country name from the location
merged_df['Country'] = merged_df['Location'].astype(str).apply(lambda x:x.split(',')[-1])

# %%
merged_df.drop('Location',axis=1,inplace=True) # droping the location column
merged_df.head()
# Out:
#    User_ID   Age        ISBN  Book_Rating           Book_Title  \
# 0        2  18.0  0195153448            0  Classical Mythology
# 1        8   NaN  0002005018            5         Clara Callan
# 2    11400  49.0  0002005018            0         Clara Callan
# 3    11676   NaN  0002005018            8         Clara Callan
# 4    41385   NaN  0002005018            0         Clara Callan
#
#             Book_Author  Year_Of_Publication                Publisher  Country
# 0    Mark P. O. Morford               2002.0  Oxford University Press      usa
# 1  Richard Bruce Wright               2001.0    HarperFlamingo Canada   canada
# 2  Richard Bruce Wright               2001.0    HarperFlamingo Canada   canada
# 3  Richard Bruce Wright               2001.0    HarperFlamingo Canada      n/a
# 4  Richard Bruce Wright               2001.0    HarperFlamingo Canada   canada

# %%
unique_values(merged_df)
# Out:
#                 Column  No of Unique Values
# 0              User_ID                70290
# 1                  Age                  128
# 2                 ISBN                97971
# 3          Book_Rating                   11
# 4           Book_Title                88822
# 5          Book_Author                40088
# 6  Year_Of_Publication                   88
# 7            Publisher                 7476
# 8              Country                  246

# %%
# replacing the missing value from the contry column
merged_df['Country'].unique()
merged_df['Country'] = merged_df['Country'].replace(' ','other').replace(' n/a','other')

# %%
merged_df
# Out:
#         User_ID   Age        ISBN  Book_Rating  \
# 0             2  18.0  0195153448            0
# 1             8   NaN  0002005018            5
# 2         11400  49.0  0002005018            0
# 3         11676   NaN  0002005018            8
# 4         41385   NaN  0002005018            0
# ...         ...   ...         ...          ...
# 673336   278418   NaN  0816748187            0
# 673337   278418   NaN  0932826466            0
# 673338   278418   NaN  1578560209            0
# 673339   278634   NaN  0425173569            0
# 673340   278843  28.0  1558508287            0
#
#                                                Book_Title  \
# 0                                     Classical Mythology
# 1                                            Clara Callan
# 2                                            Clara Callan
# 3                                            Clara Callan
# 4                                            Clara Callan
# ...                                                   ...
# 673336                           Don't Look In The Mirror
# 673337                The Deep Heart's Core is a Suitcase
# 673338                   War Paint (Secret Sisters No. 6)
# 673339  We'Ve Got Spirit: The Life and Times of Americ...
# 673340  The Everything Wedding Organizer; Checklists, ...
#
#                  Book_Author  Year_Of_Publication                 Publisher  \
# 0         Mark P. O. Morford               2002.0   Oxford University Press
# 1       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 2       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 3       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 4       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# ...                      ...                  ...                       ...
# 673336        Larry Weinberg               1998.0      Troll Communications
# 673337          Lisa Fishman               1996.0   New Issues Poetry Press
# 673338           Sandra Byrd               1998.0          Waterbrook Press
# 673339      James T. McElroy               2000.0  Berkley Publishing Group
# 673340           Laura Morin               1997.0   Adams Media Corporation
#
#         Country
# 0           usa
# 1        canada
# 2        canada
# 3         other
# 4        canada
# ...         ...
# 673336      usa
# 673337      usa
# 673338      usa
# 673339      usa
# 673340      usa
#
# [673341 rows x 9 columns]

# %%
merged_df.isnull().sum()
# Out:
# User_ID                     0
# Age                    183662
# ISBN                        0
# Book_Rating                 0
# Book_Title                  0
# Book_Author                 0
# Year_Of_Publication         2
# Publisher                   2
# Country                     0
# dtype: int64

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # Import Libraries
